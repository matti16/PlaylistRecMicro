# %% [markdown]
# # <hr style="clear: both" />
#
# # Running Spark in YARN-client mode
#
# This notebook demonstrates how to set up a SparkContext that uses SURFsara's Hadoop cluster: [YARN resourcemanager](http://head05.hathi.surfsara.nl:8088/cluster) (note you will need to be authenticated via kerberos on your machine to visit the resourcemanager link) for executors.
#
# First initialize kerberos via a Jupyter terminal.
# In the terminal execute: <BR>
# <i>kinit -k -t data/robertop.keytab robertop@CUA.SURFSARA.NL</i><BR>
# Print your credentials:

# %%
! klist
# Out:
# Ticket cache: FILE:/tmp/krb5cc_1000
# Default principal: robertop@CUA.SURFSARA.NL
#
# Valid starting       Expires              Service principal
# 04/26/2016 14:23:44  04/27/2016 14:23:44  krbtgt/CUA.SURFSARA.NL@CUA.SURFSARA.NL
# 	renew until 04/26/2016 14:23:44

# %%
! hdfs dfs -ls 
execfile('../spark-scripts/bullet.py')
# Out:
# Found 5 items
# drwx------   - robertop hdfs          0 2016-04-27 06:00 .Trash
# drwxr-xr-x   - robertop hdfs          0 2016-04-28 06:11 .sparkStaging
# drwx------   - robertop hdfs          0 2016-04-06 15:54 .staging
# drwxr-xr-x   - robertop hdfs          0 2016-04-27 13:07 mattia
# drwxr-xr-x   - robertop hdfs          0 2016-04-13 10:00 recsys2016Competition

# %% [markdown]
# Verify that we can browse HDFS:

# %% [markdown]
# Next initialize Spark. Note that the code below starts a job on the Hadoop cluster that will remain running while the notebook is active. Please close and halt the notebook when you are done. Starting the SparkContext can take a little longer. You can check the YARN resourcemanager to see the current status/usage of the cluster.

# %%
import os
os.environ['PYSPARK_PYTHON'] = '/usr/local/bin/python2.7'

HDFS_PATH = "hdfs://hathi-surfsara"

from pyspark import SparkConf, SparkContext
from pyspark.sql import SQLContext
sconf = SparkConf()

# Master is now yarn-client. The YARN and hadoop config is read from the environment
sconf.setMaster("yarn-client")

# You can control many Spark settings via the SparkConf. This determines the amount of executors on the cluster:
sconf.set("spark.executor.instances", "200")
#sconf.set("spark.executor.memory", "20g")

# UFW (firewall) is active on the VM. We explicitly opened these ports and Spark should not bind to random ports:
sconf.set("spark.driver.port", 51800)
sconf.set("spark.fileserver.port", 51801)
sconf.set("spark.broadcast.port", 51802)
sconf.set("spark.replClassServer.port", 51803)
sconf.set("spark.blockManager.port", 51804)
sconf.set("spark.authenticate", True)
sconf.set("spark.yarn.keytab", "/home/jovyan/work/data/robertop.keytab")
sconf.set("spark.yarn.access.namenodes", HDFS_PATH + ":8020")

try:
    sc = SparkContext(conf=sconf)
    sqlCtx = SQLContext(sc) 
    sendNotificationToMattia("Spark Context", "Ready!")
except Exception, err:
    sendNotificationToMattia("Fuck you!", str(err)) 
    print str(err)

# %% [markdown]
# # <hr style="clear: both" />
#
# # Now you can run your code
#
# Pick a clustering algorithm (name of the file that provides a classify(x,y [,threshold]) function)

# %%
execfile('../spark-scripts/conventions.py')
execfile('../spark-scripts/splitCluster.py')
execfile('../spark-scripts/eval.py')
execfile('../spark-scripts/implicitPlaylistAlgoFunctions.py')
execfile('../spark-scripts/implicitPlaylistAlgoMain.py')

CLUSTER_ALGO = 'jaccardBase'
THRESHOLD = 0.751

# %% [markdown]
# # Reading the conf file

# %%
import json
import copy

BASE_PATH = HDFS_PATH + '/user/robertop/mattia'

conf = {}

conf['split'] = {}
conf['split']['reclistSize'] = 100
conf['split']['callParams'] = {}
conf['split']['excludeAlreadyListenedTest'] = True
conf['split']['name'] = 'SenzaRipetizioni_1'
conf['split']['split'] = conf['split']['name']
conf['split']['minEventsPerUser'] = 5
conf['split']['inputData'] = HDFS_PATH + '/user/robertop/mattia/clusterBase.split/SenzaRipetizioni_1'
#conf['split']['inputData'] = 's3n://contentwise-research-poli/30musicdataset/newFormat/relations/sessions.idomaar'
conf['split']['bucketName'] = BASE_PATH
conf['split']['percUsTr'] = 0.05
conf['split']['ts'] = int(0.75 * (1421745857 - 1390209860) + 1390209860) - 10000
conf['split']['minEventPerSession'] = 5
conf['split']['onlineTrainingLength'] = 5
conf['split']['GTlength'] = 1
conf['split']['minEventPerSessionTraining'] = 10
conf['split']['minEventPerSessionTest'] = 11
conf['split']['mode'] = 'session'
conf['split']['forceSplitCreation'] = False
conf['split']["prop"] = {'reclistSize': conf['split']['reclistSize']}
conf['split']['type'] = None
conf['split']['out'] = HDFS_PATH + '/user/robertop/mattia/clusterBase.split/'
conf['split']['location'] = '30Mdataset/relations/sessions'

conf['evaluation'] = {}
conf['evaluation']['metric'] = {}
conf['evaluation']['metric']['type'] = 'recall'
conf['evaluation']['metric']['prop'] = {}
conf['evaluation']['metric']['prop']['N'] = [1,2,5,10,15,20,25,50,100]
conf['evaluation']['name'] = 'recall@N'

conf['general'] = {}
conf['general']['clientname'] = "clusterBase.split"
conf['general']['bucketName'] = BASE_PATH
conf['general']['tracksPath'] = '30Mdataset/entities/tracks.idomaar.gz'

conf['algo'] = {}
conf['algo']['name'] = 'ClusterBase'
conf['algo']['props'] = {}
# ***** EXAMPLE OF CONFIGURATION *****#
conf['algo']['props']["sessionJaccardShrinkage"] = 5
conf['algo']['props']["clusterSimilarityThreshold"] = 0.1
conf['algo']['props']["expDecayFactor"] = 0.7
# ****** END EXAMPLE ****************#

# %%
SPLIT_NEEDED = False
if SPLIT_NEEDED:
    try:
        splitter(conf)
        sendNotificationToMattia("Splitted", "Train and Test")
    except Exception, err:
        print str(err)
        sendNotificationToMattia("Fuck you!", str(err))

# %% [markdown]
# # Load data

# %%
clusterSongsFileRDD = sc.pickleFile(BASE_PATH + '/clusters/' + CLUSTER_ALGO + str(THRESHOLD)[2:])

songToClusterRDD = clusterSongsFileRDD.flatMap(lambda x: [(int(i), x[0]) for i in x[1]] )

print songToClusterRDD.take(3)

import json
execfile('../spark-scripts/utilsCluster.py')
train, test = loadDataset(conf)

print train.take(1)
print test.take(1)
# Out:
# [(221540, 0), (287144, 1), (41679, 2)]
# [u'{"id": "1880599", "linkedinfo": {"subjects": [{"type": "user", "id": 25088}], "objects": [{"playratio": null, "playstart": 0, "action": "play", "playtime": 217, "type": "track", "id": 4463481}, {"playratio": 0.99, "playstart": 217, "action": "play", "playtime": 193, "type": "track", "id": 3721462}, {"playratio": 0.99, "playstart": 410, "action": "play", "playtime": 256, "type": "track", "id": 1918267}, {"playratio": 0.99, "playstart": 666, "action": "play", "playtime": 151, "type": "track", "id": 1320280}, {"playratio": 0.99, "playstart": 817, "action": "play", "playtime": 205, "type": "track", "id": 2468464}, {"playratio": 0.99, "playstart": 1022, "action": "play", "playtime": 320, "type": "track", "id": 1619933}, {"playratio": 1.0, "playstart": 1342, "action": "play", "playtime": 266, "type": "track", "id": 2228799}, {"playratio": 0.99, "playstart": 1608, "action": "play", "playtime": 292, "type": "track", "id": 1879248}, {"playratio": 0.99, "playstart": 1900, "action": "play", "playtime": 231, "type": "track", "id": 2599314}, {"playratio": 0.99, "playstart": 2131, "action": "play", "playtime": 300, "type": "track", "id": 1457143}, {"playratio": 1.25, "playstart": 2431, "action": "play", "playtime": 401, "type": "track", "id": 3562199}, {"playratio": null, "playstart": 2832, "action": null, "playtime": -1, "type": "track", "id": 435470}]}, "type": "event.session", "properties": {"playtime": 2831, "numtracks": 12}, "ts": "1399069849"}']
# [u'{"linkedinfo": {"objects": [{"playratio": 0.99, "playstart": 0, "action": "play", "playtime": 153, "type": "track", "id": 2876891}, {"playratio": 0.98, "playstart": 153, "action": "play", "playtime": 104, "type": "track", "id": 3439559}, {"playratio": null, "playstart": 257, "action": "play", "playtime": 268, "type": "track", "id": 4916971}, {"playratio": 1.01, "playstart": 525, "action": "play", "playtime": 217, "type": "track", "id": 1217575}, {"playratio": 0.99, "playstart": 742, "action": "play", "playtime": 186, "type": "track", "id": 3448900}], "subjects": [{"type": "user", "id": 25088}]}, "properties": {"reclistSize": 100}, "type": "request", "id": 2508801419798318, "ts": "1419798318"}']

# %%
songToClusterRDD.count()
# Out:
# 4519105

# %% [markdown]
# # Flat (TrackID, (Index, Rec))  and Join with Song -> Cluster

# %%
def flat_map_tracks_ids(x):
    objects = x['linkedinfo']['objects']
    result = []
    for i in range(len(objects)):
        result.append( (objects[i]['id'], (i, x)) )
    return result

trainFlat = train.map(lambda x: json.loads(x)).flatMap(flat_map_tracks_ids)
train_pre_count = trainFlat.count()

trainJoin = trainFlat.join(songToClusterRDD)
train_post_count = trainJoin.count()

print "Number of entries in train before: " + str(train_pre_count)
print "Number of entries in train after: " + str(train_post_count)
sendNotificationToMattia("JOINED TRAIN" , "Number of entries in train before: " + str(train_pre_count) + "Number of entries in train after: " + str(train_post_count))



testFlat = test.map(lambda x: json.loads(x)).flatMap(flat_map_tracks_ids)
test_pre_count = testFlat.count()

testJoin = testFlat.join(songToClusterRDD)
test_post_count = testJoin.count()

print "Number of entries in train before: " + str(test_pre_count)
print "Number of entries in train after: " + str(test_post_count)
sendNotificationToMattia("JOINED TRAIN" , "Number of entries in train before: " + str(test_pre_count) + "Number of entries in train after: " + str(test_post_count))

# %% [markdown]
# # Extract Rec and Group by key (Rec)

# %%
trainSub = trainJoin.map(lambda x: (json.dumps(x[1][0][1]), (x[1][0][0], x[1][1])))
trainAgg = trainSub.groupByKey().mapValues(list)
print trainAgg.take(1)

testSub = testJoin.map(lambda x: (json.dumps(x[1][0][1]), (x[1][0][0], x[1][1])))
testAgg = testSub.groupByKey().mapValues(list)
print testAgg.take(1)
# Out:
# [('{"id": "2438680", "linkedinfo": {"subjects": [{"type": "user", "id": 23286}], "objects": [{"playratio": 1.0, "playstart": 0, "action": "play", "playtime": 399, "type": "track", "id": 1533993}, {"playratio": 1.0, "playstart": 399, "action": "play", "playtime": 252, "type": "track", "id": 1534755}, {"playratio": 1.0, "playstart": 651, "action": "play", "playtime": 342, "type": "track", "id": 1534551}, {"playratio": 1.0, "playstart": 993, "action": "play", "playtime": 352, "type": "track", "id": 1533916}, {"playratio": 0.79, "playstart": 1345, "action": "play", "playtime": 258, "type": "track", "id": 1534850}, {"playratio": 1.0, "playstart": 1603, "action": "play", "playtime": 318, "type": "track", "id": 1534543}, {"playratio": 1.0, "playstart": 1921, "action": "play", "playtime": 234, "type": "track", "id": 1534448}, {"playratio": 1.0, "playstart": 2155, "action": "play", "playtime": 272, "type": "track", "id": 1534321}, {"playratio": 1.0, "playstart": 2427, "action": "play", "playtime": 212, "type": "track", "id": 1534109}, {"playratio": 1.0, "playstart": 2639, "action": "play", "playtime": 272, "type": "track", "id": 1534398}, {"playratio": 2.86, "playstart": 2911, "action": "play", "playtime": 521, "type": "track", "id": 1534719}, {"playratio": 1.02, "playstart": 3432, "action": "play", "playtime": 212, "type": "track", "id": 2836694}, {"playratio": 0.45, "playstart": 3644, "action": "play", "playtime": 289, "type": "track", "id": 2892573}, {"playratio": 1.01, "playstart": 3933, "action": "play", "playtime": 206, "type": "track", "id": 1199868}, {"playratio": 0.78, "playstart": 4139, "action": "play", "playtime": 231, "type": "track", "id": 3590689}, {"playratio": 1.0, "playstart": 4370, "action": "play", "playtime": 211, "type": "track", "id": 1681487}, {"playratio": 0.99, "playstart": 4581, "action": "play", "playtime": 190, "type": "track", "id": 3221680}, {"playratio": 0.99, "playstart": 4771, "action": "play", "playtime": 202, "type": "track", "id": 2326345}, {"playratio": 1.01, "playstart": 4973, "action": "play", "playtime": 186, "type": "track", "id": 1625901}, {"playratio": 1.02, "playstart": 5159, "action": "play", "playtime": 156, "type": "track", "id": 2905008}, {"playratio": 0.85, "playstart": 5315, "action": "play", "playtime": 279, "type": "track", "id": 1942904}, {"playratio": null, "playstart": 5594, "action": "play", "playtime": 262, "type": "track", "id": 8809}, {"playratio": 1.0, "playstart": 5856, "action": "play", "playtime": 223, "type": "track", "id": 2327871}, {"playratio": 1.01, "playstart": 6079, "action": "play", "playtime": 176, "type": "track", "id": 2120151}, {"playratio": 1.02, "playstart": 6255, "action": "play", "playtime": 248, "type": "track", "id": 1039147}, {"playratio": 1.01, "playstart": 6503, "action": "play", "playtime": 183, "type": "track", "id": 1040937}, {"playratio": 5.67, "playstart": 6686, "action": "play", "playtime": 227, "type": "track", "id": 450598}, {"playratio": 0.81, "playstart": 6913, "action": "play", "playtime": 171, "type": "track", "id": 8894}, {"playratio": 1.02, "playstart": 7084, "action": "play", "playtime": 233, "type": "track", "id": 2023951}, {"playratio": 1.01, "playstart": 7317, "action": "play", "playtime": 203, "type": "track", "id": 2756488}, {"playratio": 0.99, "playstart": 7520, "action": "play", "playtime": 196, "type": "track", "id": 1942752}, {"playratio": 1.0, "playstart": 7716, "action": "play", "playtime": 188, "type": "track", "id": 816050}, {"playratio": 1.01, "playstart": 7904, "action": "play", "playtime": 296, "type": "track", "id": 2293542}, {"playratio": 1.06, "playstart": 8200, "action": "play", "playtime": 205, "type": "track", "id": 3156553}, {"playratio": 1.01, "playstart": 8405, "action": "play", "playtime": 225, "type": "track", "id": 2328216}, {"playratio": 1.0, "playstart": 8630, "action": "play", "playtime": 252, "type": "track", "id": 2847381}, {"playratio": 1.01, "playstart": 8882, "action": "play", "playtime": 155, "type":  ...
# [('{"linkedinfo": {"objects": [{"playratio": 1.0, "playstart": 0, "action": "play", "playtime": 195, "type": "track", "id": 3721462}, {"playratio": 0.99, "playstart": 195, "action": "play", "playtime": 184, "type": "track", "id": 3721124}, {"playratio": 1.02, "playstart": 379, "action": "play", "playtime": 182, "type": "track", "id": 3721253}, {"playratio": 1.02, "playstart": 561, "action": "play", "playtime": 193, "type": "track", "id": 3721364}, {"playratio": 1.01, "playstart": 754, "action": "play", "playtime": 173, "type": "track", "id": 3721308}], "subjects": [{"type": "user", "id": 36526}]}, "type": "request", "id": 3652601418979679, "ts": "1418979679", "properties": {"reclistSize": 100}}', [(1, 1323861), (2, 1410513), (4, 1504844), (3, 969505), (0, 407878)])]

# %% [markdown]
# # Plug Cluster IDs

# %%
def plug_clusters(x):
    row_dic = json.loads(x[0])
    to_be_plugged = x[1]
    for i in to_be_plugged:
        index = i[0]
        cl_id = i[1]
        row_dic['linkedinfo']['objects'][index]['id'] = cl_id
    return json.dumps(row_dic)
    
trainRDD = trainAgg.map(plug_clusters)
print trainRDD.take(100)

testRDD = testAgg.map(plug_clusters)
print trainRDD.take(100)
# Out:
# ['{"linkedinfo": {"subjects": [{"type": "user", "id": 23286}], "objects": [{"playratio": 1.0, "playstart": 0, "action": "play", "playtime": 399, "type": "track", "id": 3205169}, {"playratio": 1.0, "playstart": 399, "action": "play", "playtime": 252, "type": "track", "id": 2511657}, {"playratio": 1.0, "playstart": 651, "action": "play", "playtime": 342, "type": "track", "id": 2888593}, {"playratio": 1.0, "playstart": 993, "action": "play", "playtime": 352, "type": "track", "id": 2984022}, {"playratio": 0.79, "playstart": 1345, "action": "play", "playtime": 258, "type": "track", "id": 460297}, {"playratio": 1.0, "playstart": 1603, "action": "play", "playtime": 318, "type": "track", "id": 1147454}, {"playratio": 1.0, "playstart": 1921, "action": "play", "playtime": 234, "type": "track", "id": 1000156}, {"playratio": 1.0, "playstart": 2155, "action": "play", "playtime": 272, "type": "track", "id": 1749401}, {"playratio": 1.0, "playstart": 2427, "action": "play", "playtime": 212, "type": "track", "id": 2649692}, {"playratio": 1.0, "playstart": 2639, "action": "play", "playtime": 272, "type": "track", "id": 4213550}, {"playratio": 2.86, "playstart": 2911, "action": "play", "playtime": 521, "type": "track", "id": 1005605}, {"playratio": 1.02, "playstart": 3432, "action": "play", "playtime": 212, "type": "track", "id": 1214527}, {"playratio": 0.45, "playstart": 3644, "action": "play", "playtime": 289, "type": "track", "id": 3578314}, {"playratio": 1.01, "playstart": 3933, "action": "play", "playtime": 206, "type": "track", "id": 187923}, {"playratio": 0.78, "playstart": 4139, "action": "play", "playtime": 231, "type": "track", "id": 3231003}, {"playratio": 1.0, "playstart": 4370, "action": "play", "playtime": 211, "type": "track", "id": 2296508}, {"playratio": 0.99, "playstart": 4581, "action": "play", "playtime": 190, "type": "track", "id": 17805}, {"playratio": 0.99, "playstart": 4771, "action": "play", "playtime": 202, "type": "track", "id": 1589171}, {"playratio": 1.01, "playstart": 4973, "action": "play", "playtime": 186, "type": "track", "id": 4079267}, {"playratio": 1.02, "playstart": 5159, "action": "play", "playtime": 156, "type": "track", "id": 954564}, {"playratio": 0.85, "playstart": 5315, "action": "play", "playtime": 279, "type": "track", "id": 2710228}, {"playratio": null, "playstart": 5594, "action": "play", "playtime": 262, "type": "track", "id": 1953011}, {"playratio": 1.0, "playstart": 5856, "action": "play", "playtime": 223, "type": "track", "id": 123978}, {"playratio": 1.01, "playstart": 6079, "action": "play", "playtime": 176, "type": "track", "id": 3486232}, {"playratio": 1.02, "playstart": 6255, "action": "play", "playtime": 248, "type": "track", "id": 1599322}, {"playratio": 1.01, "playstart": 6503, "action": "play", "playtime": 183, "type": "track", "id": 601409}, {"playratio": 5.67, "playstart": 6686, "action": "play", "playtime": 227, "type": "track", "id": 1262805}, {"playratio": 0.81, "playstart": 6913, "action": "play", "playtime": 171, "type": "track", "id": 2245090}, {"playratio": 1.02, "playstart": 7084, "action": "play", "playtime": 233, "type": "track", "id": 3286009}, {"playratio": 1.01, "playstart": 7317, "action": "play", "playtime": 203, "type": "track", "id": 4222517}, {"playratio": 0.99, "playstart": 7520, "action": "play", "playtime": 196, "type": "track", "id": 4240311}, {"playratio": 1.0, "playstart": 7716, "action": "play", "playtime": 188, "type": "track", "id": 790507}, {"playratio": 1.01, "playstart": 7904, "action": "play", "playtime": 296, "type": "track", "id": 183880}, {"playratio": 1.06, "playstart": 8200, "action": "play", "playtime": 205, "type": "track", "id": 2039547}, {"playratio": 1.01, "playstart": 8405, "action": "play", "playtime": 225, "type": "track", "id": 2700935}, {"playratio": 1.0, "playstart": 8630, "action": "play", "playtime": 252, "type": "track", "id": 291594}, {"playratio": 1.01, "playstart": 8882, "action": "play", "playtime": 155, "type": "track", "id": 20656 ...
# ['{"id": "2223510", "linkedinfo": {"subjects": [{"type": "user", "id": 34909}], "objects": [{"playratio": 0.18, "playstart": 0, "action": "play", "playtime": 195, "type": "track", "id": 1183818}, {"playratio": 1.01, "playstart": 195, "action": "play", "playtime": 198, "type": "track", "id": 2044977}, {"playratio": 1.34, "playstart": 393, "action": "play", "playtime": 267, "type": "track", "id": 2023640}, {"playratio": 0.95, "playstart": 660, "action": "play", "playtime": 257, "type": "track", "id": 1863119}, {"playratio": 0.66, "playstart": 917, "action": "play", "playtime": 170, "type": "track", "id": 957044}, {"playratio": 1.51, "playstart": 1087, "action": "play", "playtime": 255, "type": "track", "id": 2220357}, {"playratio": 0.96, "playstart": 1342, "action": "play", "playtime": 247, "type": "track", "id": 894986}, {"playratio": 1.27, "playstart": 1589, "action": "play", "playtime": 315, "type": "track", "id": 1200080}, {"playratio": 0.79, "playstart": 1904, "action": "play", "playtime": 239, "type": "track", "id": 2266029}, {"playratio": 0.69, "playstart": 2143, "action": "play", "playtime": 146, "type": "track", "id": 1312466}, {"playratio": null, "playstart": 2289, "action": null, "playtime": -1, "type": "track", "id": 1072862}]}, "type": "event.session", "properties": {"playtime": 2288, "numtracks": 11}, "ts": "1397387845"}', '{"linkedinfo": {"subjects": [{"type": "user", "id": 23286}], "objects": [{"playratio": 1.0, "playstart": 0, "action": "play", "playtime": 399, "type": "track", "id": 3205169}, {"playratio": 1.0, "playstart": 399, "action": "play", "playtime": 252, "type": "track", "id": 2511657}, {"playratio": 1.0, "playstart": 651, "action": "play", "playtime": 342, "type": "track", "id": 2888593}, {"playratio": 1.0, "playstart": 993, "action": "play", "playtime": 352, "type": "track", "id": 2984022}, {"playratio": 0.79, "playstart": 1345, "action": "play", "playtime": 258, "type": "track", "id": 460297}, {"playratio": 1.0, "playstart": 1603, "action": "play", "playtime": 318, "type": "track", "id": 1147454}, {"playratio": 1.0, "playstart": 1921, "action": "play", "playtime": 234, "type": "track", "id": 1000156}, {"playratio": 1.0, "playstart": 2155, "action": "play", "playtime": 272, "type": "track", "id": 1749401}, {"playratio": 1.0, "playstart": 2427, "action": "play", "playtime": 212, "type": "track", "id": 2649692}, {"playratio": 1.0, "playstart": 2639, "action": "play", "playtime": 272, "type": "track", "id": 4213550}, {"playratio": 2.86, "playstart": 2911, "action": "play", "playtime": 521, "type": "track", "id": 1005605}, {"playratio": 1.02, "playstart": 3432, "action": "play", "playtime": 212, "type": "track", "id": 1214527}, {"playratio": 0.45, "playstart": 3644, "action": "play", "playtime": 289, "type": "track", "id": 3578314}, {"playratio": 1.01, "playstart": 3933, "action": "play", "playtime": 206, "type": "track", "id": 187923}, {"playratio": 0.78, "playstart": 4139, "action": "play", "playtime": 231, "type": "track", "id": 3231003}, {"playratio": 1.0, "playstart": 4370, "action": "play", "playtime": 211, "type": "track", "id": 2296508}, {"playratio": 0.99, "playstart": 4581, "action": "play", "playtime": 190, "type": "track", "id": 17805}, {"playratio": 0.99, "playstart": 4771, "action": "play", "playtime": 202, "type": "track", "id": 1589171}, {"playratio": 1.01, "playstart": 4973, "action": "play", "playtime": 186, "type": "track", "id": 4079267}, {"playratio": 1.02, "playstart": 5159, "action": "play", "playtime": 156, "type": "track", "id": 954564}, {"playratio": 0.85, "playstart": 5315, "action": "play", "playtime": 279, "type": "track", "id": 2710228}, {"playratio": null, "playstart": 5594, "action": "play", "playtime": 262, "type": "track", "id": 1953011}, {"playratio": 1.0, "playstart": 5856, "action": "play", "playtime": 223, "type": "track", "id": 123978}, {"playratio": 1.01, "playstart": 6079, "action": "play", "playtime": 176, "type": "track", "id": 3486232}, {"playratio": 1.02, "pla ...

# %%
import json
execfile('../spark-scripts/utilsCluster.py')
trainRDD, testRDD = loadDataset(conf)

from os import path
basePath = path.join(conf['general']['bucketName'], conf['general']['clientname'])
splitPath = path.join(basePath, conf['split']['name'])

clusterSim = 0.1
sessionJaccardShrinkage = 5
expDecay = 0.7

conf['split']['excludeAlreadyListenedTest'] = str(True)
conf['algo']['props']["sessionJaccardShrinkage"] = sessionJaccardShrinkage
conf['algo']['props']["clusterSimilarityThreshold"] = clusterSim
conf['algo']['props']["expDecayFactor"] = expDecay
conf['algo']['name'] = CLUSTER_ALGO + str(THRESHOLD)[2:] + '_ImplicitPlaylist_shk_%d_clustSim_%.3f_decay_%.3f' % \
                    (sessionJaccardShrinkage, clusterSim, expDecay )
            

try:
    playlists = extractImplicitPlaylists(trainRDD, conf).cache()
    sendNotificationToMattia("Playlist extracted", "Let's go!") 
    
    recJsonRDD = executeImplicitPlaylistAlgo(playlists, testRDD, conf)
    sendNotificationToMattia("Recommendation done", "Let's go!") 
    
    saveRecommendations(conf, recJsonRDD, overwrite=True)
    sendNotificationToMattia("Written!!!", "Let's go!")    
except Exception, err:
    print str(err)
    sendNotificationToMattia("Fuck you!", str(err))
# Out:
# Recommendations successfully written to hdfs://hathi-surfsara/user/robertop/mattia/clusterBase.split/Rec/plain0_ImplicitPlaylist_shk_5_clustSim_0100_decay_0700_5#07#01/recommendations
