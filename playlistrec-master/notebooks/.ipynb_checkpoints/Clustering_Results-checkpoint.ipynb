# %% [markdown]
# # <hr style="clear: both" />
#
# # Running Spark in YARN-client mode
#
# This notebook demonstrates how to set up a SparkContext that uses SURFsara's Hadoop cluster: [YARN resourcemanager](http://head05.hathi.surfsara.nl:8088/cluster) (note you will need to be authenticated via kerberos on your machine to visit the resourcemanager link) for executors.
#
# First initialize kerberos via a Jupyter terminal.
# In the terminal execute: <BR>
# <i>kinit -k -t data/robertop.keytab robertop@CUA.SURFSARA.NL</i><BR>
# Print your credentials:

# %%
! klist
# Out:
# Ticket cache: FILE:/tmp/krb5cc_1000
# Default principal: robertop@CUA.SURFSARA.NL
#
# Valid starting       Expires              Service principal
# 05/07/2016 09:58:14  05/08/2016 09:58:14  krbtgt/CUA.SURFSARA.NL@CUA.SURFSARA.NL
# 	renew until 05/07/2016 09:58:14

# %%
! hdfs dfs -ls 
execfile('../spark-scripts/bullet.py')
# Out:
# Found 5 items
# drwx------   - robertop hdfs          0 2016-05-07 06:00 .Trash
# drwxr-xr-x   - robertop hdfs          0 2016-05-07 11:32 .sparkStaging
# drwx------   - robertop hdfs          0 2016-04-06 15:54 .staging
# drwxr-xr-x   - robertop hdfs          0 2016-04-27 13:07 mattia
# drwxr-xr-x   - robertop hdfs          0 2016-04-13 10:00 recsys2016Competition

# %% [markdown]
# Verify that we can browse HDFS:

# %% [markdown]
# Next initialize Spark. Note that the code below starts a job on the Hadoop cluster that will remain running while the notebook is active. Please close and halt the notebook when you are done. Starting the SparkContext can take a little longer. You can check the YARN resourcemanager to see the current status/usage of the cluster.

# %%
import os
os.environ['PYSPARK_PYTHON'] = '/usr/local/bin/python2.7'

HDFS_PATH = "hdfs://hathi-surfsara"

from pyspark import SparkConf, SparkContext
from pyspark.sql import SQLContext
sconf = SparkConf()

# Master is now yarn-client. The YARN and hadoop config is read from the environment
sconf.setMaster("yarn-client")

# You can control many Spark settings via the SparkConf. This determines the amount of executors on the cluster:
sconf.set("spark.executor.instances", "10")
#sconf.set("spark.executor.memory", "10g")

# UFW (firewall) is active on the VM. We explicitly opened these ports and Spark should not bind to random ports:
sconf.set("spark.driver.port", 51800)
sconf.set("spark.fileserver.port", 51801)
sconf.set("spark.broadcast.port", 51802)
sconf.set("spark.replClassServer.port", 51803)
sconf.set("spark.blockManager.port", 51804)
sconf.set("spark.authenticate", True)
sconf.set("spark.yarn.keytab", "/home/jovyan/work/data/robertop.keytab")
sconf.set("spark.yarn.access.namenodes", HDFS_PATH + ":8020")

try:
    sc = SparkContext(conf=sconf)
    sqlCtx = SQLContext(sc) 
    sendNotificationToMattia("Spark Context", str(sc))
except Exception, err:
    sendNotificationToMattia("Fuck you!", str(err)) 
    print str(err)

# %% [markdown]
# # <hr style="clear: both" />
#
# # Now you can run your code

# %% [markdown]
# # Load all the results

# %%
import json

DATA_PATH = '/home/jovyan/work/data/mattia/results'


metrics = ['recall@N', 'precision@N']
algos = ['original', 'jaccardBase751']
application = ['full', 'eval']
eval_type = ['ideal', 'loss', 'flat']

results = {}



#Load original results
algo = algos[0]
results[algo] = {}
for m in metrics:
    with open(os.path.join(DATA_PATH, algo, m), 'r') as f:
        res = []
        for line in f.readlines() :
            res.append(json.loads(line))
    results[algo][m] = res
    
    
#Load Clustering result
for algo in algos[1:]:
    results[algo] = {}
    
    for a in application:
        results[algo][a] = {}
        eval_type = ['ideal', 'loss', 'flat'] if a == 'full' else ['ideal', 'loss']
        
        for e in eval_type:
            results[algo][a][e] = {}
            
            for m in metrics:
                res = []
                with open(os.path.join(DATA_PATH, algo, a, e, m), 'r') as f:
                    for line in f.readlines() :
                        res.append(json.loads(line))
                
                results[algo][a][e][m] = res

# %%
def extract_results(x):
    new_results = {}
    for i in x:
        evaluation = i['evaluation']
        N = evaluation['N']
        values = evaluation['value']
        new_results[N] = values
    return new_results

font_title = {'family': 'serif',
                   'weight': 'normal',
                   'verticalalignment': 'bottom',
                   'size': 16}  


font_labels = {'family': 'serif',
                   'weight': 'normal',
                   'size': 14}

# %% [markdown]
# # Compare Performances of Orginal VS Cluster Flat

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

N = [1, 2, 5, 10, 15, 20, 25]

LINE_W = 1.25

#Compare Performances of Orginal VS Cluster Flat
original_result = results['original']

cluster_algos = algos[1:]

for i,alg in enumerate(cluster_algos):
    flat_results = results[alg]['full']['flat']
    
    plt.figure(1+i, figsize=(15,5))
    plt.title("Original VS Flatting " + alg, fontdict = font_title)
    
    for j,m in enumerate(metrics):
        original = [ extract_results(original_result[m])[i] for i in N ]
        
        clust_flat = [ extract_results(flat_results[m])[i] for i in N ]
        plt.subplot(121 + j)
        
        plt.ylabel(m ,fontdict = font_labels)
        plt.xlabel('N', fontdict = font_labels)
        
        plt.plot(N, original, 'b', linewidth = LINE_W)
        plt.plot(N, clust_flat, 'y', linewidth = LINE_W)
        
        plt.legend(['Original', 'Flatting clusters'], fontsize = 10, loc=7)
    plt.show()

# %% [markdown]
# # Compare Clustering Full VS Only Train

# %%
for i,alg in enumerate(cluster_algos):
    full_ideal_results = results[alg]['full']['ideal']
    eval_ideal_results = results[alg]['eval']['ideal']
    
    plt.figure(1+i, figsize=(15,5))
    plt.title("Cluster Full VS Only Evaluation " + alg, fontdict = font_title)
    
    for j,m in enumerate(metrics):
        full_ideal = [ extract_results(full_ideal_results[m])[i] for i in N ]
        
        eval_ideal = [ extract_results(eval_ideal_results[m])[i] for i in N ]
        
        plt.subplot(121 + j)
        
        plt.ylabel(m ,fontdict = font_labels)
        plt.xlabel('N', fontdict = font_labels)
        
        plt.plot(N, full_ideal, 'g', linewidth = LINE_W)
        plt.plot(N, eval_ideal, 'r', linewidth = LINE_W)
        
        plt.legend(['Full', 'Clusters in Rec'], fontsize = 10, loc=7)
    plt.show()

# %% [markdown]
# # Compare Original, Cluster Ideal and with Loss

# %%
original_result = results['original']

for i,alg in enumerate(cluster_algos):
    full_ideal_results = results[alg]['full']['ideal']
    full_loss_results = results[alg]['full']['loss']
    
    plt.figure(1+i, figsize=(15,5))
    plt.title("Cluster Full VS Only Evaluation " + alg, fontdict = font_title)
    
    for j,m in enumerate(metrics):
        original = [ extract_results(original_result[m])[i] for i in N ]
        
        full_ideal = [ extract_results(full_ideal_results[m])[i] for i in N ]
        
        full_loss = [ extract_results(full_loss_results[m])[i] for i in N ]
        
        plt.subplot(121 + j)
        
        plt.ylabel(m ,fontdict = font_labels)
        plt.xlabel('N', fontdict = font_labels)
        
        plt.plot(N, original, 'b', linewidth = LINE_W)
        plt.plot(N, full_ideal, 'g', linewidth = LINE_W)
        plt.plot(N, full_loss, 'r', linewidth = LINE_W)
        
        plt.legend(['Original', 'Ideal', 'With Loss'], fontsize = 10, loc=7)
    plt.show()

# %% [markdown]
# # General Comparison

# %%
original_result = results['original']

for i,alg in enumerate(cluster_algos):
    full_ideal_results = results[alg]['full']['ideal']
    eval_ideal_results = results[alg]['eval']['ideal']
    flat_results = results[alg]['full']['flat']
    
    plt.figure(1+i, figsize=(15,5))
    plt.title("Cluster Full VS Only Evaluation " + alg, fontdict = font_title)
    
    for j,m in enumerate(metrics):
        original = [ extract_results(original_result[m])[i] for i in N ]
        
        full_ideal = [ extract_results(full_ideal_results[m])[i] for i in N ]
        
        flat = [ extract_results(flat_results[m])[i] for i in N ]
        
        eval_ideal = [ extract_results(eval_ideal_results[m])[i] for i in N ]
        
        plt.subplot(121 + j)
        
        plt.ylabel(m ,fontdict = font_labels)
        plt.xlabel('N', fontdict = font_labels)
        
        plt.plot(N, original, 'b', linewidth = LINE_W)
        plt.plot(N, full_ideal, 'g', linewidth = LINE_W)
        plt.plot(N, flat, 'y--', linewidth = LINE_W)
        plt.plot(N, eval_ideal, 'r', linewidth = LINE_W)
        
        plt.legend(['Original', 'Ideal', 'Flat', 'Clusters in Rec'], fontsize = 10, loc=7)
    plt.show()

# %%
original_result = results['original']

for i,alg in enumerate(cluster_algos):
    full_ideal_results = results[alg]['full']['ideal']
    eval_ideal_results = results[alg]['eval']['ideal']
    flat_results = results[alg]['full']['flat']
    
    plt.figure(1+i, figsize=(6,6))
    plt.title("General Comparison " + alg, fontdict = font_title)
    plt.ylabel('Precision' ,fontdict = font_labels)
    plt.xlabel('Recall', fontdict = font_labels)
    
    
    original = {'Precision': [ extract_results(original_result['precision@N'])[i] for i in N ],
                'Recall' : [ extract_results(original_result['recall@N'])[i] for i in N ]}
        
    full_ideal = {'Precision': [ extract_results(full_ideal_results['precision@N'])[i] for i in N ],
                'Recall' : [ extract_results(full_ideal_results['recall@N'])[i] for i in N ]}
        
    flat = {'Precision': [ extract_results(flat_results['precision@N'])[i] for i in N ],
            'Recall' : [ extract_results(flat_results['recall@N'])[i] for i in N ]}
        
    eval_ideal = {'Precision': [ extract_results(eval_ideal_results['precision@N'])[i] for i in N ],
                  'Recall' : [ extract_results(eval_ideal_results['recall@N'])[i] for i in N ]}
    
    plt.axis([0, 0.2, 0, 0.1])
    
        
    plt.plot(original['Recall'] , original['Precision'], 'b', linewidth = LINE_W)
    
    plt.plot(full_ideal['Recall'], full_ideal['Precision'], 'g', linewidth = LINE_W)
    plt.plot(flat['Recall'], flat['Precision'], 'y--', linewidth = LINE_W)
    plt.plot(eval_ideal['Recall'], eval_ideal['Precision'], 'r', linewidth = LINE_W)
        
    plt.legend(['Original', 'Ideal', 'Flat', 'Clusters in Rec'], fontsize = 10, loc=7)
    plt.show()
